# %% [markdown]
# # Assignment 4: Text Classifier
# ### Max Davish | PPDS Spring 17
#
# For this assignment, I'll scrape the reviews of a movies from [Roger Ebert's website](http://www.rogerebert.com/reviews) and use the text data to predict whether a review will be positive or negative.

# %%
import requests
from lxml import html

# %% [markdown]
# ### Step 1: Fetching the Data

# %%
#A useful function:
def GetHTML(URL):
    return html.fromstring((requests.get(URL)).text)

# %%
#Let's scrape some data from the main reviews page, which contains links to all the other reviews.
RE_ReviewsPage = GetHTML('http://www.rogerebert.com/reviews')
links = [link for link in  RE_ReviewsPage.xpath('//*[contains(concat( " ", @class, " " ), concat( " ", "title", " " ))]//a/@href')]
#Here are the links to other reviews pages:
for link in links:
    print(link)
# Out:
# /reviews/colossal-2017
# /reviews/their-finest-2017
# /reviews/graduation-2017
# /reviews/your-name-2017
# /reviews/going-in-style-2017
# /reviews/win-it-all-2017
# /reviews/smurfs-the-lost-village-2017
# /reviews/queen-of-the-desert-2017
# /reviews/mine-2017
# /reviews/the-assignment-2017
# /reviews/salt-and-fire-2017
# /reviews/gifted-2017
# /reviews/aftermath-2017
# /reviews/the-ticket-2017
# /reviews/all-these-sleepless-nights-2017
# /reviews/the-void-2017
# /reviews/five-came-back-2017
# /reviews/live-cargo-2017
# /reviews/ghost-in-the-shell-2017
# /reviews/carrie-pilby-2017
# /reviews/the-discovery-2017
# /reviews/david-lynch-the-art-life-2017
# /reviews/all-this-panic-2017
# /reviews/god-knows-where-i-am-2017

# %%
#Unfortunately, the original page has only 24 reviews on it, BUT it loads more as you scroll down.
    #To access even more movies, let's try to mess around with some JSON calls we found deep in the HTML.
    #(We could do this ad infinitum, but we'll start with just the first 50 pages).

import requests
from lxml import html 
    
for page in range(0,50):
    #The reviews page contains within it a hidden API, with the following parameters.
    original_url = "http://www.rogerebert.com/reviews"
    parameters = {"great_movies":0,
        "no_stars":0,
        "order":"newest",
        "title":"spot",
        "page":page}

    new_page = requests.get(url=original_url, params=parameters)
    new_page = html.fromstring(new_page.text)
    new_links = new_page.xpath('//*[contains(concat( " ", @class, " " ), concat( " ", "title", " " ))]//a/@href')
    links += [newlink for newlink in new_links]
    
print("Now we have data on "+str(len(links))+" movie reviews.")
# Out:
# Now we have data on 1224 movie reviews.

# %%
#Now that we have the list of the links to 1000+ movie reviews, let's write functions that extract important data from those URLs
#We'll write a function that extracts the review text from a given link URL:
def ExtractReview(extension):
    root = "http://www.rogerebert.com"
    ext = str(extension)
    final_url = root + ext
    tempHTML = GetHTML(final_url)
    snippets = tempHTML.xpath('//*[contains(concat( " ", @class, " " ), concat( " ", "entry", " " ))]//div//p')
    fullreview = ""
    for snippet in snippets:
        fullreview = fullreview + snippet.text_content()
    
    return fullreview

# %%
#And another much shorter function to extract the rating:
def ExtractRating(extension):
    root = "http://www.rogerebert.com"
    ext = str(extension)
    final_url = root + ext
    tempHTML = GetHTML(final_url)
    stars = tempHTML.xpath("//meta[@itemprop='ratingValue']/@content")
    try:
        return float(stars[0])
    except IndexError:
        return 2
    #For some reason there is one single page in the dataset for which this XPath query encounters an error.
    #We'll arbitrarily assign that review a rating of 2.

# %%
#For posterity, let's also get the author and the title.
    #For our present purposes, we won't need these. But they may be useful in the future.
def ExtractAuthor(extension):
    root = "http://www.rogerebert.com"
    ext = str(extension)
    final_url = root + ext
    tempHTML = GetHTML(final_url)
    try:
        author = tempHTML.xpath('//*[contains(concat( " ", @class, " " ), concat( " ", "byline", " " ))]//a//span')[0].text_content()
        return author
    except IndexError:
        return "N/A"
    #For whatever reason, a small percentage of these pages don't follow our usual Xpath format. We'll account for those.

def ExtractTitle(extension):
    root = "http://www.rogerebert.com"
    ext = str(extension)
    final_url = root + ext
    tempHTML = GetHTML(final_url)
    title = tempHTML.xpath('//h1')[0].text_content()
    return title

# %%
#Now let's create a list of dictionaries that contians the name of each movie, number of stars, and review content.
    #To do this, we need to iterate through the list of links above.
    #NOTE: This takes a really long time (roughly 3 minutes depending on your processing power)!
    
data = []
for link in links:
    title = ExtractTitle(link)
    author = ExtractAuthor(link)
    review = ExtractReview(link)
    rating = ExtractRating(link)
    datapoint = {"Title" : title, "Author": author, "Rating" : rating, "Review" : review, "GoodReview" : rating>3}
    data.append(datapoint)
    
#That worked surprisingly well!

# %%
#Let's get a sense of what the data looks like:
import pandas
pandas.DataFrame(data)
# Out:
#                      Author GoodReview  Rating  \
# 0         Matt Zoller Seitz       True     3.5
# 1          Susan Wloszczyna      False     3.0
# 2          Godfrey Cheshire       True     4.0
# 3           Brian Tallerico       True     3.5
# 4            Christy Lemire      False     2.5
# 5           Sheila O'Malley      False     2.5
# 6          Peter Sobczynski      False     2.0
# 7     Angelica Jade Bastien      False     1.0
# 8           Brian Tallerico      False     2.5
# 9          Peter Sobczynski      False     3.0
# 10               Nick Allen      False     1.0
# 11              Glenn Kenny      False     3.0
# 12             Simon Abrams      False     2.0
# 13          Brian Tallerico      False     2.0
# 14             Scout Tafoya      False     2.5
# 15             Simon Abrams      False     1.5
# 16          Brian Tallerico       True     3.5
# 17    Angelica Jade Bastien      False     2.0
# 18    Angelica Jade Bastien      False     2.0
# 19           Christy Lemire      False     3.0
# 20          Sheila O'Malley      False     1.5
# 21                      N/A       True     3.5
# 22                      N/A       True     3.5
# 23                      N/A      False     2.0
# 24        Matt Zoller Seitz       True     3.5
# 25         Susan Wloszczyna      False     3.0
# 26         Godfrey Cheshire       True     4.0
# 27          Brian Tallerico       True     3.5
# 28           Christy Lemire      False     2.5
# 29          Sheila O'Malley      False     2.5
# ...                     ...        ...     ...
# 1194       Peter Sobczynski      False     2.0
# 1195        Brian Tallerico      False     3.0
# 1196       Godfrey Cheshire      False     2.0
# 1197             Nick Allen      False     2.5
# 1198           Simon Abrams      False     1.5
# 1199            Glenn Kenny      False     1.0
# 1200        Brian Tallerico      False     2.0
# 1201            Glenn Kenny      False     2.5
# 1202        Sheila O'Malley      False     3.0
# 1203           Simon Abrams      False     2.0
# 1204        Brian Tallerico      False     3.0
# 1205        Brian Tallerico      False     1.5
# 1206         Odie Henderson       True     3.5
# 1207       Godfrey Cheshire       True     4.0
# 1208      Matt Zoller Seitz      False     3.0
# 1209      Matt Zoller Seitz      False     2.5
# 1210        Brian Tallerico      False     1.5
# 1211            Glenn Kenny       True     3.5
# 1212        Brian Tallerico       True     4.0
# 1213       Susan Wloszczyna      False     2.5
# 1214       Peter Sobczynski       True     3.5
# 1215        Sheila O'Malley      False     3.0
# 1216       Godfrey Cheshire      False     1.5
# 1217         Odie Henderson      False     2.5
# 1218        Brian Tallerico      False     3.0
# 1219        Brian Tallerico      False     1.5
# 1220        Sheila O'Malley      False     2.5
# 1221           Simon Abrams      False     3.0
# 1222       Peter Sobczynski      False     1.5
# 1223            Glenn Kenny      False     2.5
#
#                                                  Review  \
# 0     What if Godzilla was a projection of your issu...
# 1     When there is a global call to arms, the uplif...
# 2     A fascinating and fastidiously complex study o...
# 3     “I feel like I’m always searching for somethin...
# 4     The original “Going in Style,” from 1979, was ...
# 5     A desperate gambler, in a financial hole, isn'...
# 6     When the brain trust at Sony Pictures Animatio...
# 7     Early in “Queen of the Desert,” Gertrude Bell’...
# 8     Fabio Guaglione & Fabio Resinaro’s “Mine” is p...
# 9     “The Assignment” is a film that arrives in the...
# 10    “Salt and Fire” is what happens when a great d...
# 11    This might sound like a typically cynical movi...
# 12    "Aftermath," a new revenge drama starring Arno...
# 13    There’s a story told several times in Ido Fluk...
# 14    Michal Marczak's “All These Sleepless Nights” ...
# 15    Have you ever wanted to like a movie so much b...
# 16    Netflix's "Five Came Back," based on the book ...
# 17    The sky is often caught in the midst of a turb...
# 18    “Ghost in the Shell” is full of dazzling image...
# 19    There is an entire subgenre of movie comedy in...
# 20    The first scene of "The Discovery" shows the t...
# 21    From “Hitchcock/Truffaut” to “De Palma,” the f...
# 22    Regardless of how far removed you might be fro...
# 23    Glowing sunrises and sunsets. Long-deserted ap...
# 24    What if Godzilla was a projection of your issu...
# 25    When there is a global call to arms, the uplif...
# 26    A fascinating and fastidiously complex study o...
# 27    “I feel like I’m always searching for somethin...
# 28    The original “Going in Style,” from 1979, was ...
# 29    A desperate gambler, in a financial hole, isn'...
# ...                                                 ...
# 1194  At a time\r\nwhen every action-oriented film t...
# 1195  Leah Meyerhoff is a major new talent. Her “I B...
# 1196  Another film about junkies? That question almo...
# 1197  While some\r\nfilmmakers desire to fill their ...
# 1198  "Sunset Edge," a coming-of-age drama that's al...
# 1199  The first feature by co-writer/director Raj Am...
# 1200  “Can the government use hacking techniques to ...
# 1201  “His purity was a very attractive quality,” sa...
# 1202  Madeleine (Adele Haenel) does not know that sh...
# 1203  Note: Roger Ebert didn't give "Human Centipede...
# 1204  It’s impossible to watch “When Marnie Was Ther...
# 1205  Rarely has a remake felt more contractually ob...
# 1206  “The Farewell Party” is a bittersweet tragicom...
# 1207  Right off the bat, Alonso Ruizpalacios’ “Güero...
# 1208  Early in Brad Bird's science fiction adventure...
# 1209  Written and directed by "Gattaca" filmmaker an...
# 1210  Oren Peli is a little obsessed with people goi...
# 1211  It’s always a pleasure to see Blythe Danner in...
# 1212  George Miller’s “Mad Max” films didn’t just ma...
# 1213  As second rounds of comedies go, “Pitch Perfec...
# 1214  Attempting\r\nto make a companion to "The Fren...
# 1215  The thing about drug addicts is that, regardle...
# 1216  “Slow West” must be counted one of the most un...
# 1217  “In the Name of My Daughter” is the seventh An...
# 1218  HBO’s “Bessie,” premiering Saturday on the net...
# 1219  What went wrong? How did so many talented peop...
# 1220  If we agree with famous Baltimore contrarian H...
# 1221  The key to a good interview is adaptability. A...
# 1222  The\r\ninfrequency of the Western genre tempts...
# 1223  “What’s the highest grossing Swedish movie of ...
#
#                                                   Title
# 0                                              Colossal
# 1                                          Their Finest
# 2                                            Graduation
# 3                                             Your Name
# 4                                        Going in Style
# 5                                            Win It All
# 6                              Smurfs: The Lost Village
# 7                                   Queen of the Desert
# 8                                                  Mine
# 9                                        The Assignment
# 10                                        Salt and Fire
# 11                                               Gifted
# 12                                            Aftermath
# 13                                           The Ticket
# 14                           All These Sleepless Nights
# 15                                             The Void
# 16                                       Five Came Back
# 17                                           Live Cargo
# 18                                   Ghost in the Shell
# 19                                         Carrie Pilby
# 20                                        The Discovery
# 21                            David Lynch: The Art Life
# 22                                       All This Panic
# 23                                 God Knows Where I Am
# 24                                             Colossal
# 25                                         Their Finest
# 26                                           Graduation
# 27                                            Your Name
# 28                                       Going in Style
# 29                                           Win It All
# ...                                                 ...
# 1194                                           Survivor
# 1195                              I Believe in Unicorns
# 1196                                  Heaven Knows What
# 1197                                    Uncertain Terms
# 1198                                        Sunset Edge
# 1199                                          Unfreedom
# 1200                                           Deep Web
# 1201                                  Sunshine Superman
# 1202                                Love at First Fight
# 1203             The Human Centipede 3 (Final Sequence)
# 1204                              When Marnie Was There
# 1205                                        Poltergeist
# 1206                                 The Farewell Party
# 1207                                             Güeros
# 1208                                       Tomorrowland
# 1209                                          Good Kill
# 1210                                            Area 51
# 1211                          I'll See You in My Dreams
# 1212                                 Mad Max: Fury Road
# 1213                                    Pitch Perfect 2
# 1214                                     The Connection
# 1215                                            Animals
# 1216                                          Slow West
# 1217                         In the Name of My Daughter
# 1218                                             Bessie
# 1219                                 Every Secret Thing
# 1220                                    The Film Critic
# 1221                        Dark Star: HR Giger’s World
# 1222                                      Echoes Of War
# 1223  The 100-Year-Old Man Who Climbed Out the Windo...
#
# [1224 rows x 5 columns]

# %% [markdown]
# ### Step 2/3: Specify Documents and Classes
# For this project, we'll define each "document" as an entire movie review and the two classes as simply "good reviews" and "bad reviews", good reviews being reviews that scored 3.5 or 4 stars, and bad reviews being all others.

# %% [markdown]
# ### Step 4 Tokenize/featurize the document
# We'll consider each feature a new word that is an adjective, noun, verb, or adverb. We will remove stopwords.

# %%
#Our data is  not appropriate for the NLTK classifier.
#What we need is a LIST of TUPLES where [0] is a DICTIONARY where the features are keys and [1] is the classification.
    #To do this, we'll recycle Panos's code. 
    
import nltk
from nltk.corpus import stopwords
import random
stop_words = stopwords.words('english')

#First, write a function to featureize...
def features(document):
    sent_tokens = nltk.word_tokenize(document)
    document_words = nltk.pos_tag(sent_tokens)
    features = {}
    for word, pos in document_words:
        if (pos.startswith('NN') or pos.startswith('V') or pos.startswith('J') or pos.startswith('A')):
            features['%s/%s' % (word, pos)] = True
    return features

# %%
#And then loop through the data...
labeled_features = []
for datapoint in data:
    tag = datapoint["GoodReview"]
    feats = features(datapoint["Review"])
    labeled_features.append((feats, tag))
