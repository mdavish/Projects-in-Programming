# %% [markdown]
# # Movies
# Max Davish, Christian Miljkovic, & Rosanna Rodriguez
#
# Projects in Programming and Data Science
#
# See project proposal [here](https://www.maxdavish.com/s/Moneyballing-the-Movies-Project-Proposal.htm).

# %% [markdown]
# ## Part I: Scraping Box Office Data
# The first step is to get the most important data - the box office data for movies. A key problem, however, is simply _finding_ all the movies on BoxOfficeMojo's website. To solve this problem, we'll visit the [yearly box office](http://www.boxofficemojo.com/yearly/) page, which we can then use to visit another set of [pages that list the top movies](http://www.boxofficemojo.com/yearly/chart/?yr=2017&p=.htm) from each year.
#
# From this list let's choose to get data on, say, the top 100 movies at the box office from every year between 1990 and 2017.
#
# Now let's define some useful functions and variables that we need to scrape the data.

# %%
#A function for getting HTML pages:
def GetHTML(URL):
    import requests
    from lxml import html 
    return html.fromstring((requests.get(URL,stream=True)).text,)

#Here are some useful variables to define for future functions:
#These help us locate particular data points in the data tables within the HTML pages above.
xp_partA = '//td//td//tr[(((count(preceding-sibling::*) + 1) = '
xp_partB = ') and parent::*)]//td[(((count(preceding-sibling::*) + 1) = '
xp_partC = ') and parent::*)]'

title_index  = 2
studio_index = 3
boxoffice_index = 4
theaters_index = 5
openingweekend_index = 6
date_index = 8

#This is a separate function needed to get the URLs embedded in some of those data points.
#NOTE: It requires the webpage to be defined OUTSIDE the function, which may seem odd, but...

    #It's important to understand the reason behind our defining the URL outside of the function - 
    #By doing so, getPoint function XPath queries a static object in our data ... 
    # ... rather than re-requerying the URL for every single point
    #This drastically reduces the amount of time this process will take for the entire website
    #(Although it will still be highly time-consuming)

def getURL(row):
    link_xp = '//td//td//tr[(((count(preceding-sibling::*) + 1) = '+str(row+1)+') and parent::*)]//b//a/@href'
    link = webpage.xpath(link_xp)[0]
    root = 'http://www.boxofficemojo.com'
    return root+link

#Webpage is still defined outside the function:
def getPoint(row,column):
    xp = xp_partA + str(row) + xp_partB + str(column) + xp_partC
    return webpage.xpath(xp)[0].text_content()

#Here, both the webpage AND the year are defined outside of the function. 
#This is also appropriate for the upcoming loop.
def getTable():
    table = []
    for i in range(2,102):
        newrow = {"Title": getPoint(i,title_index),
                  "URL": getURL((i-1)),
                  "Studio": getPoint(i,studio_index),
                  "Box_Office": getPoint(i,boxoffice_index),
                  "Theaters": getPoint(i,theaters_index),
                  "Opening_Weekend": getPoint(i,openingweekend_index),
                  #Like the URL, the date must be defined OUTSIDE of the function
                  "Release_Date": str(getPoint(i,date_index))+'/'+str(year),
        }
        table.append(newrow)
    return table

# %% [markdown]
# Using these functions, we can easily loop through BoxOfficeMojo URLs and compile our data.
# This will take a LONG time, so be patient...
#
# _(It's roughly a 4 minute process if you choose only the top 100 movies from 1980-2017)_

# %%
data = []
for year in range(2017,1980, -1):
    page = 1
    url = "http://www.boxofficemojo.com/yearly/chart/?page="+str(page)+"&view=releasedate&view2=domestic&yr="+str(year)+"&p=.htm"
    webpage = GetHTML(url)
    data += getTable()
    
len(data)
# Out:
# 3700

# %%
import pandas
df = pandas.DataFrame(data)
df
# Out:
#         Box_Office Opening_Weekend Release_Date   Studio Theaters  \
# 0     $481,009,028    $174,750,616    3/17/2017       BV    4,210
# 1     $224,572,433     $88,411,916     3/3/2017      Fox    4,071
# 2     $194,608,240     $98,786,705    4/14/2017     Uni.    4,329
# 3     $174,705,216     $53,003,468    2/10/2017       WB    4,088
# 4     $172,687,155     $33,377,060    2/24/2017     Uni.    3,143
# 5     $165,568,393     $61,025,472    3/10/2017       WB    3,846
# 6     $149,206,615     $50,198,902    3/31/2017      Fox    3,829
# 7     $138,124,620     $40,010,975    1/20/2017     Uni.    3,373
# 8     $114,434,010     $46,607,250    2/10/2017     Uni.    3,714
# 9      $92,029,184     $30,436,123    2/10/2017     LG/S    3,113
# 10     $84,285,410     $40,300,288    3/24/2017      LGF    3,693
# 11     $64,235,580     $18,222,810    1/27/2017     Uni.    3,178
# 12     $57,027,388     $16,172,119     3/3/2017     LG/S    2,888
# 13     $45,157,105     $18,469,620    2/17/2017     Uni.    3,328
# 14     $44,898,413     $20,130,142    1/20/2017     Par.    3,651
# 15     $39,996,354     $18,676,033    3/31/2017     Par.    3,440
# 16     $38,158,272     $13,210,449     4/7/2017     Sony    3,610
# 17     $37,647,145     $11,932,330     4/7/2017  WB (NL)    3,076
# 18     $33,370,166     $10,950,705    1/13/2017     Par.    3,119
# 19     $32,187,017     $12,201,873    2/17/2017  WB (NL)    3,185
# 20     $30,353,973     $13,688,751     1/6/2017     SGem    3,070
# 21     $29,854,730     $12,501,936    3/24/2017     Sony    3,146
# 22     $27,793,018     $13,002,632     2/3/2017     Par.    2,931
# 23     $26,830,068     $13,601,682    1/27/2017     SGem    3,104
# 24     $22,395,806     $13,501,349    1/13/2017      STX    2,220
# 25     $20,783,704      $8,344,128    1/13/2017      ORF    1,803
# 26     $18,369,044      $7,722,802    3/24/2017       WB    2,464
# 27     $16,164,791        $446,380     4/7/2017     FoxS    2,215
# 28     $14,905,220      $3,288,835    3/31/2017    Focus    1,057
# 29     $13,147,952      $3,967,885     4/7/2017      PFR    1,386
# ...            ...             ...          ...      ...      ...
# 3670    $8,124,257         $64,713    8/19/1981       WB      N/A
# 3671    $7,886,857      $2,765,456    3/13/1981     Uni.      N/A
# 3672    $7,258,543        $189,000   12/11/1981      MGM      248
# 3673    $6,950,125             N/A    2/15/1981      MGM      N/A
# 3674    $6,468,195             N/A   10/16/1981      MGM      N/A
# 3675    $6,400,000             N/A    2/13/1981      Fox      N/A
# 3676    $5,732,587             N/A    8/28/1981     Par.      N/A
# 3677    $5,672,031             N/A    2/11/1981     Par.      N/A
# 3678    $5,504,218             N/A    4/10/1981     Par.      N/A
# 3679    $5,484,132             N/A    2/13/1981      MGM      N/A
# 3680    $5,165,432      $1,582,148     8/7/1981     Par.      N/A
# 3681    $5,000,000             N/A    10/7/1981       BV      N/A
# 3682    $4,454,295      $1,392,852     3/6/1981     Uni.      N/A
# 3683    $3,702,028      $1,214,767   11/13/1981     Uni.      N/A
# 3684    $3,256,082         $63,356    10/2/1981     Uni.      N/A
# 3685    $3,082,096             N/A    5/15/1981     Par.      N/A
# 3686    $3,007,436             N/A    2/13/1981      MGM      N/A
# 3687    $2,869,425             N/A    7/23/1981     Par.      N/A
# 3688    $2,863,642         $18,225    3/13/1981     Col.      N/A
# 3689    $2,447,576        $566,736    4/24/1981       WB      N/A
# 3690    $2,154,696        $407,464   12/18/1981     Uni.      N/A
# 3691    $2,028,612        $429,146    4/10/1981       WB      N/A
# 3692    $2,022,771        $439,564    2/13/1981       WB      N/A
# 3693    $2,004,742        $939,423    8/21/1981     Uni.      N/A
# 3694    $1,976,198        $287,081    9/18/1981     Uni.      N/A
# 3695    $1,791,147        $958,637     5/1/1981     Uni.      N/A
# 3696    $1,729,274             N/A    3/20/1981      MGM      N/A
# 3697    $1,622,898        $344,837   10/23/1981     Uni.      N/A
# 3698    $1,205,934             N/A    4/10/1981      MGM      N/A
# 3699    $1,169,875             N/A    9/11/1981     Par.      N/A
#
#                                  Title  \
# 0          Beauty and the Beast (2017)
# 1                                Logan
# 2              The Fate of the Furious
# 3                The LEGO Batman Movie
# 4                              Get Out
# 5                   Kong: Skull Island
# 6                        The Boss Baby
# 7                                Split
# 8                  Fifty Shades Darker
# 9               John Wick: Chapter Two
# 10                Power Rangers (2017)
# 11                     A Dog's Purpose
# 12                           The Shack
# 13                      The Great Wall
# 14      xXx: The Return of Xander Cage
# 15           Ghost in the Shell (2017)
# 16            Smurfs: The Lost Village
# 17               Going in Style (2017)
# 18                      Monster Trucks
# 19                          Fist Fight
# 20              Underworld: Blood Wars
# 21                         Life (2017)
# 22                               Rings
# 23    Resident Evil: The Final Chapter
# 24                     The Bye Bye Man
# 25                           Sleepless
# 26                               CHiPs
# 27                              Gifted
# 28                The Zookeeper's Wife
# 29                 The Case for Christ
# ...                                ...
# 3670                Prince of the City
# 3671                      The Funhouse
# 3672                       Buddy Buddy
# 3673              La Cage aux Folles 2
# 3674                   All the Marbles
# 3675                        Eyewitness
# 3676                         Gallipoli
# 3677        My Bloody Valentine (1981)
# 3678                        Going Ape!
# 3679                   The Dogs of War
# 3680                    Student Bodies
# 3681          The Watcher in the Woods
# 3682                    All Night Long
# 3683        The Pursuit of D.B. Cooper
# 3684                         Zoot Suit
# 3685                    The Fan (1981)
# 3686                    The Last Metro
# 3687                               Gas
# 3688                    Modern Romance
# 3689                          The Hand
# 3690                        Heartbeeps
# 3691                     This Is Elvis
# 3692                            Sphinx
# 3693                Honky Tonk Freeway
# 3694                       Raggedy Man
# 3695              King of the Mountain
# 3696                      Cutter's Way
# 3697              Silence of the North
# 3698                From Mao to Mozart
# 3699                      Night School
#
#                                                     URL
# 0     http://www.boxofficemojo.com/movies/?id=beauty...
# 1     http://www.boxofficemojo.com/movies/?id=wolver...
# 2     http://www.boxofficemojo.com/movies/?id=furiou...
# 3     http://www.boxofficemojo.com/movies/?id=lego2.htm
# 4     http://www.boxofficemojo.com/movies/?id=blumho...
# 5     http://www.boxofficemojo.com/movies/?id=legend...
# 6     http://www.boxofficemojo.com/movies/?id=bossba...
# 7     http://www.boxofficemojo.com/movies/?id=split2...
# 8     http://www.boxofficemojo.com/movies/?id=fiftys...
# 9     http://www.boxofficemojo.com/movies/?id=johnwi...
#
# **Reminder:** For error handling, always coerce to None instead of "N/A", so that the database treats them as NULL values instead of varchars.

# %%
def CleanNumber(n):
    if n == "N/A" or n == None:
        return None
    else:
        return float((n.strip("$")).replace(",",""))

df["Box_Office"] = df["Box_Office"].apply(CleanNumber)
df["Opening_Weekend"] = df["Opening_Weekend"].apply(CleanNumber)
df["Theaters"] = df["Theaters"].apply(CleanNumber)
df["Release_Date"] = pandas.to_datetime(df["Release_Date"],errors='coerce')
df
# Out:
#        Box_Office  Opening_Weekend Release_Date   Studio  Theaters  \
# 0     481009028.0      174750616.0   2017-03-17       BV    4210.0
# 1     224572433.0       88411916.0   2017-03-03      Fox    4071.0
# 2     194608240.0       98786705.0   2017-04-14     Uni.    4329.0
# 3     174705216.0       53003468.0   2017-02-10       WB    4088.0
# 4     172687155.0       33377060.0   2017-02-24     Uni.    3143.0
# 5     165568393.0       61025472.0   2017-03-10       WB    3846.0
# 6     149206615.0       50198902.0   2017-03-31      Fox    3829.0
# 7     138124620.0       40010975.0   2017-01-20     Uni.    3373.0
# 8     114434010.0       46607250.0   2017-02-10     Uni.    3714.0
# 9      92029184.0       30436123.0   2017-02-10     LG/S    3113.0
# 10     84285410.0       40300288.0   2017-03-24      LGF    3693.0
# 11     64235580.0       18222810.0   2017-01-27     Uni.    3178.0
# 12     57027388.0       16172119.0   2017-03-03     LG/S    2888.0
# 13     45157105.0       18469620.0   2017-02-17     Uni.    3328.0
# 14     44898413.0       20130142.0   2017-01-20     Par.    3651.0
# 15     39996354.0       18676033.0   2017-03-31     Par.    3440.0
# 16     38158272.0       13210449.0   2017-04-07     Sony    3610.0
# 17     37647145.0       11932330.0   2017-04-07  WB (NL)    3076.0
# 18     33370166.0       10950705.0   2017-01-13     Par.    3119.0
# 19     32187017.0       12201873.0   2017-02-17  WB (NL)    3185.0
# 20     30353973.0       13688751.0   2017-01-06     SGem    3070.0
# 21     29854730.0       12501936.0   2017-03-24     Sony    3146.0
# 22     27793018.0       13002632.0   2017-02-03     Par.    2931.0
# 23     26830068.0       13601682.0   2017-01-27     SGem    3104.0
# 24     22395806.0       13501349.0   2017-01-13      STX    2220.0
# 25     20783704.0        8344128.0   2017-01-13      ORF    1803.0
# 26     18369044.0        7722802.0   2017-03-24       WB    2464.0
# 27     16164791.0         446380.0   2017-04-07     FoxS    2215.0
# 28     14905220.0        3288835.0   2017-03-31    Focus    1057.0
# 29     13147952.0        3967885.0   2017-04-07      PFR    1386.0
# ...           ...              ...          ...      ...       ...
# 3670    8124257.0          64713.0   1981-08-19       WB       NaN
# 3671    7886857.0        2765456.0   1981-03-13     Uni.       NaN
# 3672    7258543.0         189000.0   1981-12-11      MGM     248.0
# 3673    6950125.0              NaN   1981-02-15      MGM       NaN
# 3674    6468195.0              NaN   1981-10-16      MGM       NaN
# 3675    6400000.0              NaN   1981-02-13      Fox       NaN
# 3676    5732587.0              NaN   1981-08-28     Par.       NaN
# 3677    5672031.0              NaN   1981-02-11     Par.       NaN
# 3678    5504218.0              NaN   1981-04-10     Par.       NaN
# 3679    5484132.0              NaN   1981-02-13      MGM       NaN
# 3680    5165432.0        1582148.0   1981-08-07     Par.       NaN
# 3681    5000000.0              NaN   1981-10-07       BV       NaN
# 3682    4454295.0        1392852.0   1981-03-06     Uni.       NaN
# 3683    3702028.0        1214767.0   1981-11-13     Uni.       NaN
# 3684    3256082.0          63356.0   1981-10-02     Uni.       NaN
# 3685    3082096.0              NaN   1981-05-15     Par.       NaN
# 3686    3007436.0              NaN   1981-02-13      MGM       NaN
# 3687    2869425.0              NaN   1981-07-23     Par.       NaN
# 3688    2863642.0          18225.0   1981-03-13     Col.       NaN
# 3689    2447576.0         566736.0   1981-04-24       WB       NaN
# 3690    2154696.0         407464.0   1981-12-18     Uni.       NaN
# 3691    2028612.0         429146.0   1981-04-10       WB       NaN
# 3692    2022771.0         439564.0   1981-02-13       WB       NaN
# 3693    2004742.0         939423.0   1981-08-21     Uni.       NaN
# 3694    1976198.0         287081.0   1981-09-18     Uni.       NaN
# 3695    1791147.0         958637.0   1981-05-01     Uni.       NaN
# 3696    1729274.0              NaN   1981-03-20      MGM       NaN
# 3697    1622898.0         344837.0   1981-10-23     Uni.       NaN
# 3698    1205934.0              NaN   1981-04-10      MGM       NaN
# 3699    1169875.0              NaN   1981-09-11     Par.       NaN
#
#                                  Title  \
# 0          Beauty and the Beast (2017)
# 1                                Logan
# 2              The Fate of the Furious
# 3                The LEGO Batman Movie
# 4                              Get Out
# 5                   Kong: Skull Island
# 6                        The Boss Baby
# 7                                Split
# 8                  Fifty Shades Darker
# 9               John Wick: Chapter Two
# 10                Power Rangers (2017)
# 11                     A Dog's Purpose
# 12                           The Shack
# 13                      The Great Wall
# 14      xXx: The Return of Xander Cage
# 15           Ghost in the Shell (2017)
# 16            Smurfs: The Lost Village
# 17               Going in Style (2017)
# 18                      Monster Trucks
# 19                          Fist Fight
# 20              Underworld: Blood Wars
# 21                         Life (2017)
# 22                               Rings
# 23    Resident Evil: The Final Chapter
# 24                     The Bye Bye Man
# 25                           Sleepless
# 26                               CHiPs
# 27                              Gifted
# 28                The Zookeeper's Wife
# 29                 The Case for Christ
# ...                                ...
# 3670                Prince of the City
# 3671                      The Funhouse
# 3672                       Buddy Buddy
# 3673              La Cage aux Folles 2
# 3674                   All the Marbles
# 3675                        Eyewitness
# 3676                         Gallipoli
# 3677        My Bloody Valentine (1981)
# 3678                        Going Ape!
# 3679                   The Dogs of War
# 3680                    Student Bodies
# 3681          The Watcher in the Woods
# 3682                    All Night Long
# 3683        The Pursuit of D.B. Cooper
# 3684                         Zoot Suit
# 3685                    The Fan (1981)
# 3686                    The Last Metro
# 3687                               Gas
# 3688                    Modern Romance
# 3689                          The Hand
# 3690                        Heartbeeps
# 3691                     This Is Elvis
# 3692                            Sphinx
# 3693                Honky Tonk Freeway
# 3694                       Raggedy Man
# 3695              King of the Mountain
# 3696                      Cutter's Way
# 3697              Silence of the North
# 3698                From Mao to Mozart
# 3699                      Night School
#
#                                                     URL
# 0     http://www.boxofficemojo.com/movies/?id=beauty...
# 1     http://www.boxofficemojo.com/movies/?id=wolver...
# 2     http://www.boxofficemojo.com/movies/?id=furiou...
# 3695  http://www.boxofficemojo.com/movies/?id=kingof...
# 3696  http://www.boxofficemojo.com/movies/?id=cutter...
# 3697  http://www.boxofficemojo.com/movies/?id=silenc...
# 3698  http://www.boxofficemojo.com/movies/?id=fromma...
# 3699  http://www.boxofficemojo.com/movies/?id=nights...
#
# [3700 rows x 7 columns]

# %% [markdown]
# We also need to add a few extra fields to this table:
# - **BoxOfficeMojo ID**, which we can extract from the URL with a RegEx
# - **IMDB_ID**, which we can use the OMDB API to find
# - **Production Budget**, which we'll also find on BoxOfficeMojo, using the BoxOffice ID
#
# Let's write functions to acquire those variables.

# %%
def Extract_BoxOfficeID(URL):
    import re
    regex = re.compile('(http:\/\/www.boxofficemojo.com\/movies\/\?id=)((\w)+)(.htm)')
    matches = regex.finditer(URL)
    for match in matches:
        return match.group(2)
    
def GetProdBudget(ID):
    try:
        url = 'http://www.boxofficemojo.com/movies/?page=daily&view=chart&id='+ID+'.htm'
    except TypeError:
        return None
    page = GetHTML(url)
    budget_xp = '//center//tr[(((count(preceding-sibling::*) + 1) = 4) and parent::*)]//b'
    budget = page.xpath(budget_xp)
    try:
        if budget[1].text_content() == 'N/A':
            return None
        else:
            return budget[1].text_content()
    except IndexError:
        return None
    
def GetIMDB_ID(title):
        #Might want to add a 'year' parameter later on, but we'll assess accuracy.
    import requests
    omdb_url = 'http://www.omdbapi.com/?'
    parameters = {'s': title, 'type':'movie'} 
    try:
        return requests.get(url = omdb_url, params = parameters).json()["Search"][0]["imdbID"]
    except KeyError:
        return None
    except ValueError: 
        #Should also catch pesky JSONDecoderError
        return None

# %% [markdown]
# Now we'll add all three columns to the dataframe. Make sure to run these cells separately - otherwise you'll run into server overload errors. _(You might anyway...)_

# %%
df["BoxOfficeID"] = df["URL"].apply(Extract_BoxOfficeID)

# %%
df["Production_Budget"] = df["BoxOfficeID"].apply(GetProdBudget)

# %% [markdown]
# **Warning:** This cell takes a _very_ long time to run (15 minutes+), so try not to run it more than once, if you can avoid it.

# %%
df["IMDB_ID"] = df["Title"].apply(GetIMDB_ID)
df
# Out:
#        Box_Office  Opening_Weekend Release_Date   Studio  Theaters  \
# 0     481009028.0      174750616.0   2017-03-17       BV    4210.0
# 1     224572433.0       88411916.0   2017-03-03      Fox    4071.0
# 2     194608240.0       98786705.0   2017-04-14     Uni.    4329.0
# 3     174705216.0       53003468.0   2017-02-10       WB    4088.0
# 4     172687155.0       33377060.0   2017-02-24     Uni.    3143.0
# 5     165568393.0       61025472.0   2017-03-10       WB    3846.0
# 6     149206615.0       50198902.0   2017-03-31      Fox    3829.0
# 7     138124620.0       40010975.0   2017-01-20     Uni.    3373.0
# 8     114434010.0       46607250.0   2017-02-10     Uni.    3714.0
# 9      92029184.0       30436123.0   2017-02-10     LG/S    3113.0
# 10     84285410.0       40300288.0   2017-03-24      LGF    3693.0
# 11     64235580.0       18222810.0   2017-01-27     Uni.    3178.0
# 12     57027388.0       16172119.0   2017-03-03     LG/S    2888.0
# 13     45157105.0       18469620.0   2017-02-17     Uni.    3328.0
# 14     44898413.0       20130142.0   2017-01-20     Par.    3651.0
# 15     39996354.0       18676033.0   2017-03-31     Par.    3440.0
# 16     38158272.0       13210449.0   2017-04-07     Sony    3610.0
# 17     37647145.0       11932330.0   2017-04-07  WB (NL)    3076.0
# 18     33370166.0       10950705.0   2017-01-13     Par.    3119.0
# 19     32187017.0       12201873.0   2017-02-17  WB (NL)    3185.0
# 20     30353973.0       13688751.0   2017-01-06     SGem    3070.0
# 21     29854730.0       12501936.0   2017-03-24     Sony    3146.0
# 22     27793018.0       13002632.0   2017-02-03     Par.    2931.0
# 23     26830068.0       13601682.0   2017-01-27     SGem    3104.0
# 24     22395806.0       13501349.0   2017-01-13      STX    2220.0
# 25     20783704.0        8344128.0   2017-01-13      ORF    1803.0
# 26     18369044.0        7722802.0   2017-03-24       WB    2464.0
# 27     16164791.0         446380.0   2017-04-07     FoxS    2215.0
# 28     14905220.0        3288835.0   2017-03-31    Focus    1057.0
# 29     13147952.0        3967885.0   2017-04-07      PFR    1386.0
# ...           ...              ...          ...      ...       ...
# 3670    8124257.0          64713.0   1981-08-19       WB       NaN
# 3671    7886857.0        2765456.0   1981-03-13     Uni.       NaN
# 3672    7258543.0         189000.0   1981-12-11      MGM     248.0
# 3673    6950125.0              NaN   1981-02-15      MGM       NaN
# 3674    6468195.0              NaN   1981-10-16      MGM       NaN
# 3675    6400000.0              NaN   1981-02-13      Fox       NaN
# 3676    5732587.0              NaN   1981-08-28     Par.       NaN
# 3677    5672031.0              NaN   1981-02-11     Par.       NaN
# 3678    5504218.0              NaN   1981-04-10     Par.       NaN
# 3679    5484132.0              NaN   1981-02-13      MGM       NaN
# 3680    5165432.0        1582148.0   1981-08-07     Par.       NaN
# 3681    5000000.0              NaN   1981-10-07       BV       NaN
# 3682    4454295.0        1392852.0   1981-03-06     Uni.       NaN
# 3683    3702028.0        1214767.0   1981-11-13     Uni.       NaN
# 3684    3256082.0          63356.0   1981-10-02     Uni.       NaN
# 3685    3082096.0              NaN   1981-05-15     Par.       NaN
# 3686    3007436.0              NaN   1981-02-13      MGM       NaN
# 3687    2869425.0              NaN   1981-07-23     Par.       NaN
# 3688    2863642.0          18225.0   1981-03-13     Col.       NaN
# 3689    2447576.0         566736.0   1981-04-24       WB       NaN
# 3690    2154696.0         407464.0   1981-12-18     Uni.       NaN
# 3691    2028612.0         429146.0   1981-04-10       WB       NaN
# 3692    2022771.0         439564.0   1981-02-13       WB       NaN
# 3693    2004742.0         939423.0   1981-08-21     Uni.       NaN
# 3694    1976198.0         287081.0   1981-09-18     Uni.       NaN
# 3695    1791147.0         958637.0   1981-05-01     Uni.       NaN
# 3696    1729274.0              NaN   1981-03-20      MGM       NaN
# 3697    1622898.0         344837.0   1981-10-23     Uni.       NaN
# 3698    1205934.0              NaN   1981-04-10      MGM       NaN
# 3699    1169875.0              NaN   1981-09-11     Par.       NaN
#
#                                  Title  \
# 0          Beauty and the Beast (2017)
# 1                                Logan
# 2              The Fate of the Furious
# 3                The LEGO Batman Movie
# 4                              Get Out
# 5                   Kong: Skull Island
# 6                        The Boss Baby
# 7                                Split
# 8                  Fifty Shades Darker
# 28           zookeeperswife                NaN  tt1730768
# 29         thecaseforchrist                NaN  tt6113488
# ...                     ...                ...        ...
# 3670        princeofthecity                NaN  tt0082945
# 3671               funhouse                NaN  tt0082427
# 3672             buddybuddy                NaN  tt0077280
# 3673       lacageauxfolles2                NaN       None
# 3674          allthemarbles                NaN  tt0081964
# 3675             eyewitness                NaN  tt0082353
# 3676              gallipoli                NaN  tt0082432
# 3677      mybloodyvalentine                NaN       None
# 3678               goingape                NaN  tt0082457
# 3679              dogsofwar                NaN  tt0080641
# 3680          studentbodies                NaN  tt0083133
# 3681      watcherinthewoods                NaN  tt0081738
# 3682           allnightlong                NaN  tt0082001
# 3683      pursuitofdbcooper                NaN  tt0082958
# 3684               zootsuit                NaN  tt0083365
# 3685                  fan81                NaN       None
# 3686              lastmetro                NaN  tt0080610
# 3687                    gas                NaN  tt0262246
# 3688          modernromance                NaN  tt0082764
# 3689                   hand                NaN  tt0104389
# 3690             heartbeeps                NaN  tt0082507
# 3691            thisiselvis                NaN  tt0083193
# 3692                 sphinx                NaN  tt0083113
# 3693       honkytonkfreeway                NaN  tt0082525
# 3694             raggedyman                NaN  tt0082969
# 3695      kingofthemountain                NaN  tt0082619
# 3696             cuttersway                NaN  tt0082220
# 3697      silenceofthenorth                NaN  tt0083079
# 3698        frommaotomozart                NaN  tt0080762
# 3699            nightschool                NaN  tt0082812
#
# [3700 rows x 10 columns]

# %% [markdown]
# Unfortunately, this process didn't work perfectly, and some of data is simply unavailable - many movies are missing a BoxOffice or IMDB ID or lack a production budget. Later on, we can revisit or functions to try to minimize these sources of error.
#
# Before we get to databasing, let's do one last cleaning measure - **converting production budgets from strings to floats.** We'll write a regex function to do this as well.

# %%
#Write the function
def CleanProdBudget(n):
    if n == None:
        return None
    else:
        import re
        regex = re.compile('([\d]+[\.]?[\d]?)( million)')
        matches = regex.finditer(n)
        for match in matches:
            return (float(match.group(1))*1000000)

# %%
df["Production_Budget"] = df["Production_Budget"].apply(CleanProdBudget)
df
# Out:
#        Box_Office  Opening_Weekend Release_Date   Studio  Theaters  \
# 0     481009028.0      174750616.0   2017-03-17       BV    4210.0
# 1     224572433.0       88411916.0   2017-03-03      Fox    4071.0
# 2     194608240.0       98786705.0   2017-04-14     Uni.    4329.0
# 3     174705216.0       53003468.0   2017-02-10       WB    4088.0
# 4     172687155.0       33377060.0   2017-02-24     Uni.    3143.0
# 5     165568393.0       61025472.0   2017-03-10       WB    3846.0
# 6     149206615.0       50198902.0   2017-03-31      Fox    3829.0
# 7     138124620.0       40010975.0   2017-01-20     Uni.    3373.0
# 8     114434010.0       46607250.0   2017-02-10     Uni.    3714.0
# 9      92029184.0       30436123.0   2017-02-10     LG/S    3113.0
# 10     84285410.0       40300288.0   2017-03-24      LGF    3693.0
# 11     64235580.0       18222810.0   2017-01-27     Uni.    3178.0
# 12     57027388.0       16172119.0   2017-03-03     LG/S    2888.0
# 13     45157105.0       18469620.0   2017-02-17     Uni.    3328.0
# 14     44898413.0       20130142.0   2017-01-20     Par.    3651.0
# 15     39996354.0       18676033.0   2017-03-31     Par.    3440.0
# 16     38158272.0       13210449.0   2017-04-07     Sony    3610.0
# 17     37647145.0       11932330.0   2017-04-07  WB (NL)    3076.0
# 18     33370166.0       10950705.0   2017-01-13     Par.    3119.0
# 19     32187017.0       12201873.0   2017-02-17  WB (NL)    3185.0
# 20     30353973.0       13688751.0   2017-01-06     SGem    3070.0
# 21     29854730.0       12501936.0   2017-03-24     Sony    3146.0
# 22     27793018.0       13002632.0   2017-02-03     Par.    2931.0
# 23     26830068.0       13601682.0   2017-01-27     SGem    3104.0
# 24     22395806.0       13501349.0   2017-01-13      STX    2220.0
# 25     20783704.0        8344128.0   2017-01-13      ORF    1803.0
# 26     18369044.0        7722802.0   2017-03-24       WB    2464.0
# 27     16164791.0         446380.0   2017-04-07     FoxS    2215.0
# 28     14905220.0        3288835.0   2017-03-31    Focus    1057.0
# 29     13147952.0        3967885.0   2017-04-07      PFR    1386.0
# ...           ...              ...          ...      ...       ...
# 3670    8124257.0          64713.0   1981-08-19       WB       NaN
# 3671    7886857.0        2765456.0   1981-03-13     Uni.       NaN
# 3672    7258543.0         189000.0   1981-12-11      MGM     248.0
# 3673    6950125.0              NaN   1981-02-15      MGM       NaN
# 3674    6468195.0              NaN   1981-10-16      MGM       NaN
# 3675    6400000.0              NaN   1981-02-13      Fox       NaN
# 3676    5732587.0              NaN   1981-08-28     Par.       NaN
# 3677    5672031.0              NaN   1981-02-11     Par.       NaN
# 3678    5504218.0              NaN   1981-04-10     Par.       NaN
# 3679    5484132.0              NaN   1981-02-13      MGM       NaN
# 3680    5165432.0        1582148.0   1981-08-07     Par.       NaN
# 3681    5000000.0              NaN   1981-10-07       BV       NaN
# 3682    4454295.0        1392852.0   1981-03-06     Uni.       NaN
# 3683    3702028.0        1214767.0   1981-11-13     Uni.       NaN
# 3684    3256082.0          63356.0   1981-10-02     Uni.       NaN
# 3685    3082096.0              NaN   1981-05-15     Par.       NaN
# 3686    3007436.0              NaN   1981-02-13      MGM       NaN
# 3687    2869425.0              NaN   1981-07-23     Par.       NaN
# 3688    2863642.0          18225.0   1981-03-13     Col.       NaN
# 3689    2447576.0         566736.0   1981-04-24       WB       NaN
# 3690    2154696.0         407464.0   1981-12-18     Uni.       NaN
# 3691    2028612.0         429146.0   1981-04-10       WB       NaN
# 3692    2022771.0         439564.0   1981-02-13       WB       NaN
# 3693    2004742.0         939423.0   1981-08-21     Uni.       NaN
# 3694    1976198.0         287081.0   1981-09-18     Uni.       NaN
# 3695    1791147.0         958637.0   1981-05-01     Uni.       NaN
# 3696    1729274.0              NaN   1981-03-20      MGM       NaN
# 3697    1622898.0         344837.0   1981-10-23     Uni.       NaN
# 3698    1205934.0              NaN   1981-04-10      MGM       NaN
# 3699    1169875.0              NaN   1981-09-11     Par.       NaN
#
#                                  Title  \
# 0          Beauty and the Beast (2017)
# 1                                Logan
# 2              The Fate of the Furious
# 3                The LEGO Batman Movie
# 4                              Get Out
# 5                   Kong: Skull Island
# 6                        The Boss Baby
# 7                                Split
# 8                  Fifty Shades Darker
# 9               John Wick: Chapter Two
# 10                Power Rangers (2017)
# 3678               goingape                NaN
# 3679              dogsofwar                NaN
# 3680          studentbodies                NaN
# 3681      watcherinthewoods                NaN
# 3682           allnightlong                NaN
# 3683      pursuitofdbcooper                NaN
# 3684               zootsuit                NaN
# 3685                  fan81                NaN
# 3686              lastmetro                NaN
# 3687                    gas                NaN
# 3688          modernromance                NaN
# 3689                   hand                NaN
# 3690             heartbeeps                NaN
# 3691            thisiselvis                NaN
# 3692                 sphinx                NaN
# 3693       honkytonkfreeway                NaN
# 3694             raggedyman                NaN
# 3695      kingofthemountain                NaN
# 3696             cuttersway                NaN
# 3697      silenceofthenorth                NaN
# 3698        frommaotomozart                NaN
# 3699            nightschool                NaN
#
# [3700 rows x 9 columns]

# %% [markdown]
# We're finally ready to insert this dataframe into a database. This dataframe will form the backbone of the database - the central table to which all others are related.

# %%
#Connection to database:
import MySQLdb as mdb
import sys

con = mdb.connect(host = 'localhost', 
                  user = 'root', 
                  passwd = 'dwdstudent2015', 
                  charset='utf8', use_unicode=True);

# %%
#This code deletes the database if it exists.
    #This is a useful cell to have while designing database, but now that the code is finished I will comment this part out.
db_name = 'Movies'
drop_db_query = 'DROP DATABASE IF EXISTS {db}'.format(db=db_name)
cursor = con.cursor()
cursor.execute(drop_db_query)
cursor.close()

#Create the database:
create_db_query = "CREATE DATABASE IF NOT EXISTS {db} DEFAULT CHARACTER SET 'utf8'".format(db=db_name)
cursor = con.cursor()
cursor.execute(create_db_query)
cursor.close()

# %%
cursor = con.cursor()
table_name = 'Movies'
create_table_query = '''CREATE TABLE IF NOT EXISTS {db}.{table}
                        (Box_Office varchar(250),
                        Opening_Weekend float,
                        Release_Date datetime,
                        Studio varchar(250),
                        Theaters int,
                        Title varchar(250),
                        BoxOfficeID varchar(250),
                        Production_Budget float,
                        IMDB_ID varchar(250),
                        PRIMARY KEY(BoxOfficeID)
                        )'''.format(db=db_name, table=table_name)
cursor.execute(create_table_query)
cursor.close()

# %%
cursor = con.cursor()
table_name = 'Movies'
db_name = 'Movies'
insert_query_template = '''INSERT IGNORE INTO {db}.{table}(Box_Office,
                        Opening_Weekend,
                        Release_Date,
                        Studio,
                        Theaters,
                        Title,
                        BoxOfficeID,
                        Production_Budget,
                        IMDB_ID)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)'''.format(db=db_name, table=table_name)
for i in range(0,len(df)):
    try:
        query_parameters = (df["Box_Office"][i],
                        df["Opening_Weekend"][i],
                        df["Release_Date"][i],
                        df["Studio"][i],
                        df["Theaters"][i],
                        df["Title"][i],
                        df["BoxOfficeID"][i],
                        df["Production_Budget"][i],
                        df["IMDB_ID"][i])
        cursor.execute(insert_query_template,query_parameters)
    except KeyError:
        continue

con.commit()
cursor.close()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:25: Warning: (1265, "Data truncated for column 'Production_Budget' at row 1")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:25: Warning: (1265, "Data truncated for column 'Opening_Weekend' at row 1")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:25: Warning: (1048, "Column 'BoxOfficeID' cannot be null")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:25: Warning: (1062, "Duplicate entry '' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:25: Warning: (1366, "Incorrect integer value: 'nan' for column 'Theaters' at row 1")

# %% [markdown]
# There you have it! We have the first table of our database. Up next - the foreign and day-by-day tables.
